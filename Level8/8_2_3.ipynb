# %% [markdown]
# # 8.2.3 Tabular Data: Display Sample Data Frame (quandl)

# %% [markdown]
# ######

# %% [markdown]
# ##### Instructions: Use the quandl library to download the same data as exercise 1.

# %%
# Set up:
import quandl
quandl.ApiConfig.api_key = 'kcpyuyvzniPXDs2Z9U57'

# Get Data
# myData = quandl.get_table('ZACKS/FC', ticker='SPGI')
spgiData = quandl.get_table('WIKI/PRICES', ticker='SPGI')

# Get only for two years.
# spgiDataFinal = quandl.get('WIKI/SPGI', start_date='2019-06-30', end_date='2021-06-30'). WONT WORK. Data only till March 2018.
spgiDataFinal = quandl.get('WIKI/SPGI', start_date='2016-06-30', end_date='2018-06-30')

spgiDataFinal
# Out:
#               Open    High     Low   Close     Volume  Ex-Dividend  \
# Date
# 2016-06-30  106.03  107.32  104.92  107.26  1709563.0          0.0
# 2016-07-01  107.11  109.10  107.11  107.86   891699.0          0.0
# 2016-07-05  107.11  107.85  105.34  106.17   958897.0          0.0
# 2016-07-06  105.15  106.89  104.75  106.78  1155886.0          0.0
# 2016-07-07  106.68  107.96  105.62  107.31   824412.0          0.0
# ...            ...     ...     ...     ...        ...          ...
# 2018-03-21  196.13  196.72  193.76  193.81  1471795.0          0.0
# 2018-03-22  192.04  193.23  188.94  189.08  1284354.0          0.0
# 2018-03-23  189.96  191.37  186.24  186.49  1194692.0          0.0
# 2018-03-26  189.85  192.75  188.14  191.28  1115763.0          0.0
# 2018-03-27  192.38  193.20  186.60  187.87  1354398.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# 2016-06-30          1.0  104.219633  105.487608  103.128585  105.428632
# ...
